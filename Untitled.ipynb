# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("train.csv")
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2 = pd.read_csv("test.csv")
df2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df1.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
x = pd.Index(df1['PassengerId'])

# %%
y = pd.Index(df2["PassengerId"])

# %%
df1.index=x

# %%
df2.index=y

# %%
df1.tail()
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 887                  887         0       2
# 888                  888         1       1
# 889                  889         0       3
# 890                  890         1       1
# 891                  891         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# PassengerId
# 887                             Montvila, Rev. Juozas    male  27.0      0
# 888                      Graham, Miss. Margaret Edith  female  19.0      0
# 889          Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 890                             Behr, Mr. Karl Howell    male  26.0      0
# 891                               Dooley, Mr. Patrick    male  32.0      0
#
#              Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887              0      211536  13.00   NaN        S
# 888              0      112053  30.00   B42        S
# ...

# %%
df2.head()
# Out:
#              PassengerId  Pclass  \
# PassengerId
# 892                  892       3
# 893                  893       3
# 894                  894       2
# 895                  895       3
# 896                  896       3
#
#                                                      Name     Sex   Age  \
# PassengerId
# 892                                      Kelly, Mr. James    male  34.5
# 893                      Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 894                             Myles, Mr. Thomas Francis    male  62.0
# 895                                      Wirz, Mr. Albert    male  27.0
# 896          Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
#
#              SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892              0      0   330911   7.8292   NaN        Q
# 893              1      0   363272   7.0000   NaN        S
# 894              0      0   240276   9.6875   NaN        Q
# ...

# %%
df_titanic = df1.append(df2, sort = False)

# %%
df_titanic.head()
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 1                      1       0.0       3
# 2                      2       1.0       1
# 3                      3       1.0       3
# 4                      4       1.0       1
# 5                      5       0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# ...

# %%
z = pd.Index(range(0,1309))

# %%
df_titanic.index=z

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
age_mean = df_titanic["Age"].mean()
age_mean
# Out:
# 29.881137667304014

# %%
df_titanic["Age"].fillna(age_mean, inplace=True)

# %%
fare_mean = df_titanic['Fare'].mean()
fare_mean
# Out:
# 33.2954792813456

# %%
df_titanic["Fare"].fillna(fare_mean, inplace=True)

# %%
survived_median = df_titanic["Survived"].median()

# %%
df_titanic["Survived"].fillna(survived_median,inplace=True)

# %%
df_titanic["Cabin"].mode()
# Out:
# 0    C23 C25 C27
# dtype: object

# %%
df_titanic.dropna(inplace = True)

# %%
df_titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df_titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2       1.0       1
# 3             4       1.0       1
# 6             7       0.0       1
# 10           11       1.0       3
# 11           12       1.0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
df_titanic.duplicated().sum()
# Out:
# 0

# %%
df_titanic["Age"].max()
# Out:
# 80.0

# %%
df_titanic["Age"].min()
# Out:
# 0.92

# %%
df_titanic[df_titanic["Age"] <= 10]
# Out:
#       PassengerId  Survived  Pclass                             Name     Sex  \
# 10             11       1.0       3  Sandstrom, Miss. Marguerite Rut  female
# 183           184       1.0       2        Becker, Master. Richard F    male
# 193           194       1.0       2       Navratil, Master. Michel M    male
# 205           206       0.0       3       Strom, Miss. Telma Matilda  female
# 297           298       0.0       1     Allison, Miss. Helen Loraine  female
# 305           306       1.0       1   Allison, Master. Hudson Trevor    male
# 340           341       1.0       2   Navratil, Master. Edmond Roger    male
# 445           446       1.0       1        Dodge, Master. Washington    male
# 618           619       1.0       2      Becker, Miss. Marion Louise  female
# 751           752       1.0       3              Moor, Master. Meier    male
# 1008         1009       0.0       3  Sandstrom, Miss. Beatrice Irene  female
# ...

# %%
df_titanic['isChild'] = 0
df_titanic.loc[df_titanic['Age'] < 15, 'isChild'] = 1

# %%
df_titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2       1.0       1
# 3               4       1.0       1
# 6               7       0.0       1
# 10             11       1.0       3
# 11             12       1.0       1
# 21             22       1.0       2
# 23             24       1.0       1
# 27             28       0.0       1
# 31             32       1.0       1
# 52             53       1.0       1
# 54             55       0.0       1
# 55             56       1.0       1
# 62             63       0.0       1
# 66             67       1.0       2
# 75             76       0.0       3
# 88             89       1.0       1
# 92             93       0.0       1
# 96             97       0.0       1
# 97             98       1.0       1
# 102           103       0.0       1
# 110           111       0.0       1
# 118           119       0.0       1
# 123           124       1.0       2
# 124           125       0.0       1
# 128           129       1.0       3
# ...

# %%
df_titanic[df_titanic["Fare"] == df_titanic["Fare"].max()]
# Out:
#       PassengerId  Survived  Pclass  \
# 679           680       1.0       1
# 737           738       1.0       1
# 1234         1235       0.0       1
#
#                                                    Name     Sex   Age  SibSp  \
# 679                  Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 737                              Lesurer, Mr. Gustave J    male  35.0      0
# 1234  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#       Parch    Ticket      Fare        Cabin Embarked  isChild
# 679       1  PC 17755  512.3292  B51 B53 B55        C        0
# 737       0  PC 17755  512.3292         B101        C        0
# 1234      1  PC 17755  512.3292  B51 B53 B55        C        0

# %%
df_titanic[df_titanic["Fare"] == df_titanic["Fare"].min()]
# Out:
#       PassengerId  Survived  Pclass                     Name   Sex        Age  \
# 263           264       0.0       1    Harrison, Mr. William  male  40.000000
# 806           807       0.0       1   Andrews, Mr. Thomas Jr  male  39.000000
# 815           816       0.0       1         Fry, Mr. Richard  male  29.881138
# 1263         1264       0.0       1  Ismay, Mr. Joseph Bruce  male  49.000000
#
#       SibSp  Parch  Ticket  Fare        Cabin Embarked  isChild
# 263       0      0  112059   0.0          B94        S        0
# 806       0      0  112050   0.0          A36        S        0
# 815       0      0  112058   0.0         B102        S        0
# 1263      0      0  112058   0.0  B52 B54 B56        S        0

# %%
df_titanic.groupby(['Survived'])["Sex"].count()
# Out:
# Survived
# 0.0    159
# 1.0    134
# Name: Sex, dtype: int64

# %%
df_titanic.groupby(['Sex', 'Survived']) ['Pclass'].count()
# Out:
# Sex     Survived
# female  0.0          50
#         1.0          89
# male    0.0         109
#         1.0          45
# Name: Pclass, dtype: int64

# %%
pvt = df_titanic.pivot_table(index=['Sex'], columns=['Pclass'], values=['Age'], aggfunc='count')
pvt
# Out:
#         Age
# Pclass    1   2  3
# Sex
# female  119  13  7
# male    135  10  9

# %%
titanic_survived = df_titanic[['Pclass','Sex','Age']][df_titanic.Survived == 1]
titanic_survived.head()
# Out:
#     Pclass     Sex   Age
# 1        1  female  38.0
# 3        1  female  35.0
# 10       3  female   4.0
# 11       1  female  58.0
# 21       2    male  34.0

# %%
titanic_survived.count()
# Out:
# Pclass    134
# Sex       134
# Age       134
# dtype: int64

# %%
titanic_unsurvived = df_titanic[['Pclass','Sex','Age']][df_titanic.Survived == 0]
titanic_unsurvived.head()
# Out:
#     Pclass   Sex   Age
# 6        1  male  54.0
# 27       1  male  19.0
# 54       1  male  65.0
# 62       1  male  45.0
# 75       3  male  25.0

# %%
titanic_unsurvived.count()
# Out:
# Pclass    159
# Sex       159
# Age       159
# dtype: int64

# %%
def labeling(x):
    if x == 'female':
        return 'F'
    else:
        return 'M'

# %%
df_titanic["Sex"] = df_titanic["Sex"].apply(labeling)

# %%
df_titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2       1.0       1
# 3             4       1.0       1
# 6             7       0.0       1
# 10           11       1.0       3
# 11           12       1.0       1
#
#                                                  Name Sex   Age  SibSp  Parch  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0      1      0
# 6                             McCarthy, Mr. Timothy J   M  54.0      0      0
# 10                    Sandstrom, Miss. Marguerite Rut   F   4.0      1      1
# 11                           Bonnell, Miss. Elizabeth   F  58.0      0      0
#
#       Ticket     Fare Cabin Embarked  isChild
# 1   PC 17599  71.2833   C85        C        0
# 3     113803  53.1000  C123        S        0
# 6      17463  51.8625   E46        S        0
# 10   PP 9549  16.7000    G6        S        1
# 11    113783  26.5500  C103        S        0

# %%
df_titanic.to_csv("Titanic.csv")

# %%
titanic_survived['Sex'].mode()
# Out:
# 0    female
# dtype: object

# %%
titanic_unsurvived['Sex'].mode()
# Out:
# 0    male
# dtype: object

# %%
sns.barplot(data = df_titanic, x='Sex', y='Survived')
# Out:
# C:\Users\HOLLYWOOD\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df_titanic['Pclass'])

# %%
df_titanic[df_titanic["Pclass"] == 1].count()
# Out:
# PassengerId    254
# Survived       254
# Pclass         254
# Name           254
# Sex            254
# Age            254
# SibSp          254
# Parch          254
# Ticket         254
# Fare           254
# Cabin          254
# Embarked       254
# isChild        254
# dtype: int64

# %%
df_titanic[df_titanic["Pclass"] == 2].count()
# Out:
# PassengerId    23
# Survived       23
# Pclass         23
# Name           23
# Sex            23
# Age            23
# SibSp          23
# Parch          23
# Ticket         23
# Fare           23
# Cabin          23
# Embarked       23
# isChild        23
# dtype: int64

# %%
df_titanic[df_titanic["Pclass"] == 3].count()
# Out:
# PassengerId    16
# Survived       16
# Pclass         16
# Name           16
# Sex            16
# Age            16
# SibSp          16
# Parch          16
# Ticket         16
# Fare           16
# Cabin          16
# Embarked       16
# isChild        16
# dtype: int64

# %%
sns.catplot(data=df_titanic, x='Embarked', y='Survived')

# %%
df_titanic[(df_titanic.Embarked == 'C') & (df_titanic.Survived == 0)].count()
# Out:
# PassengerId    66
# Survived       66
# Pclass         66
# Name           66
# Sex            66
# Age            66
# SibSp          66
# Parch          66
# Ticket         66
# Fare           66
# Cabin          66
# Embarked       66
# isChild        66
# dtype: int64

# %%
df_titanic[(df_titanic.Embarked == 'C') & (df_titanic.Survived == 1)].count()
# Out:
# PassengerId    52
# Survived       52
# Pclass         52
# Name           52
# Sex            52
# Age            52
# SibSp          52
# Parch          52
# Ticket         52
# Fare           52
# Cabin          52
# Embarked       52
# isChild        52
# dtype: int64

# %%
df_titanic[(df_titanic.Embarked == 'S') & (df_titanic.Survived == 0)].count()
# Out:
# PassengerId    90
# Survived       90
# Pclass         90
# Name           90
# Sex            90
# Age            90
# SibSp          90
# Parch          90
# Ticket         90
# Fare           90
# Cabin          90
# Embarked       90
# isChild        90
# dtype: int64

# %%
df_titanic[(df_titanic.Embarked == 'S') & (df_titanic.Survived == 1)].count()
# Out:
# PassengerId    80
# Survived       80
# Pclass         80
# Name           80
# Sex            80
# Age            80
# SibSp          80
# Parch          80
# Ticket         80
# Fare           80
# Cabin          80
# Embarked       80
# isChild        80
# dtype: int64

# %%
df_titanic[(df_titanic.Embarked == 'Q') & (df_titanic.Survived == 0)].count()
# Out:
# PassengerId    3
# Survived       3
# Pclass         3
# Name           3
# Sex            3
# Age            3
# SibSp          3
# Parch          3
# Ticket         3
# Fare           3
# Cabin          3
# Embarked       3
# isChild        3
# dtype: int64

# %%
df_titanic[(df_titanic.Embarked == 'Q') & (df_titanic.Survived == 1)].count()
# Out:
# PassengerId    2
# Survived       2
# Pclass         2
# Name           2
# Sex            2
# Age            2
# SibSp          2
# Parch          2
# Ticket         2
# Fare           2
# Cabin          2
# Embarked       2
# isChild        2
# dtype: int64

# %%
sns.countplot(df_titanic.isChild)

# %%
df_titanic[df_titanic['isChild'] == 1].count()
# Out:
# PassengerId    16
# Survived       16
# Pclass         16
# Name           16
# Sex            16
# Age            16
# SibSp          16
# Parch          16
# Ticket         16
# Fare           16
# Cabin          16
# Embarked       16
# isChild        16
# dtype: int64

# %%
sns.countplot(df_titanic.Parch)

# %%
df_titanic[df_titanic.Parch == 0].count()
# Out:
# PassengerId    2
# Survived       2
# Pclass         2
# Name           2
# Sex            2
# Age            2
# SibSp          2
# Parch          2
# Ticket         2
# Fare           2
# Cabin          2
# Embarked       2
# isChild        2
# dtype: int64

# %%
df_titanic[df_titanic.Parch == 1].count()
# Out:
# PassengerId    56
# Survived       56
# Pclass         56
# Name           56
# Sex            56
# Age            56
# SibSp          56
# Parch          56
# Ticket         56
# Fare           56
# Cabin          56
# Embarked       56
# isChild        56
# dtype: int64

# %%
df_titanic[df_titanic.Parch == 2].count()
# Out:
# PassengerId    29
# Survived       29
# Pclass         29
# Name           29
# Sex            29
# Age            29
# SibSp          29
# Parch          29
# Ticket         29
# Fare           29
# Cabin          29
# Embarked       29
# isChild        29
# dtype: int64

# %%
df_titanic[df_titanic.Parch == 3].count()
# Out:
# PassengerId    3
# Survived       3
# Pclass         3
# Name           3
# Sex            3
# Age            3
# SibSp          3
# Parch          3
# Ticket         3
# Fare           3
# Cabin          3
# Embarked       3
# isChild        3
# dtype: int64

# %%
df_titanic[df_titanic.Parch == 4].count()
# Out:
# PassengerId    2
# Survived       2
# Pclass         2
# Name           2
# Sex            2
# Age            2
# SibSp          2
# Parch          2
# Ticket         2
# Fare           2
# Cabin          2
# Embarked       2
# isChild        2
# dtype: int64

# %%
sns.countplot(df_titanic.SibSp)

# %%
df_titanic[df_titanic['SibSp'] == 0].count()
# Out:
# PassengerId    169
# Survived       169
# Pclass         169
# Name           169
# Sex            169
# Age            169
# SibSp          169
# Parch          169
# Ticket         169
# Fare           169
# Cabin          169
# Embarked       169
# isChild        169
# dtype: int64

# %%
df_titanic[df_titanic['SibSp'] == 1].count()
# Out:
# PassengerId    110
# Survived       110
# Pclass         110
# Name           110
# Sex            110
# Age            110
# SibSp          110
# Parch          110
# Ticket         110
# Fare           110
# Cabin          110
# Embarked       110
# isChild        110
# dtype: int64

# %%
df_titanic[df_titanic['SibSp'] == 2].count()
# Out:
# PassengerId    10
# Survived       10
# Pclass         10
# Name           10
# Sex            10
# Age            10
# SibSp          10
# Parch          10
# Ticket         10
# Fare           10
# Cabin          10
# Embarked       10
# isChild        10
# dtype: int64

# %%
df_titanic[df_titanic['SibSp'] == 3].count()
# Out:
# PassengerId    4
# Survived       4
# Pclass         4
# Name           4
# Sex            4
# Age            4
# SibSp          4
# Parch          4
# Ticket         4
# Fare           4
# Cabin          4
# Embarked       4
# isChild        4
# dtype: int64

# %%
df_titanic[(df_titanic.isChild == 1) & (df_titanic.Survived == 1)].count()
# Out:
# PassengerId    10
# Survived       10
# Pclass         10
# Name           10
# Sex            10
# Age            10
# SibSp          10
# Parch          10
# Ticket         10
# Fare           10
# Cabin          10
# Embarked       10
# isChild        10
# dtype: int64

# %%
df_titanic[(df_titanic.Parch == 0) & (df_titanic.Survived == 0)].count()
# Out:
# PassengerId    114
# Survived       114
# Pclass         114
# Name           114
# Sex            114
# Age            114
# SibSp          114
# Parch          114
# Ticket         114
# Fare           114
# Cabin          114
# Embarked       114
# isChild        114
# dtype: int64

# %%
df_titanic[(df_titanic.Parch == 1) & (df_titanic.Survived == 0)].count()
# Out:
# PassengerId    28
# Survived       28
# Pclass         28
# Name           28
# Sex            28
# Age            28
# SibSp          28
# Parch          28
# Ticket         28
# Fare           28
# Cabin          28
# Embarked       28
# isChild        28
# dtype: int64

# %%
df_titanic[(df_titanic.Parch == 2) & (df_titanic.Survived == 0)].count()
# Out:
# PassengerId    12
# Survived       12
# Pclass         12
# Name           12
# Sex            12
# Age            12
# SibSp          12
# Parch          12
# Ticket         12
# Fare           12
# Cabin          12
# Embarked       12
# isChild        12
# dtype: int64

# %%
df_titanic[(df_titanic.Parch == 3) & (df_titanic.Survived == 0)].count()
# Out:
# PassengerId    3
# Survived       3
# Pclass         3
# Name           3
# Sex            3
# Age            3
# SibSp          3
# Parch          3
# Ticket         3
# Fare           3
# Cabin          3
# Embarked       3
# isChild        3
# dtype: int64

# %%
df_titanic[(df_titanic.Parch == 4) & (df_titanic.Survived == 1)].count()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# isChild        0
# dtype: int64

# %%
df_titanic[(df_titanic.SibSp == 0) & (df_titanic.Survived == 1)].count()
# Out:
# PassengerId    75
# Survived       75
# Pclass         75
# Name           75
# Sex            75
# Age            75
# SibSp          75
# Parch          75
# Ticket         75
# Fare           75
# Cabin          75
# Embarked       75
# isChild        75
# dtype: int64

# %%
df_titanic[(df_titanic.SibSp == 1) & (df_titanic.Survived == 1)].count()
# Out:
# PassengerId    52
# Survived       52
# Pclass         52
# Name           52
# Sex            52
# Age            52
# SibSp          52
# Parch          52
# Ticket         52
# Fare           52
# Cabin          52
# Embarked       52
# isChild        52
# dtype: int64

# %%
df_titanic[(df_titanic.SibSp == 2) & (df_titanic.Survived == 1)].count()
# Out:
# PassengerId    5
# Survived       5
# Pclass         5
# Name           5
# Sex            5
# Age            5
# SibSp          5
# Parch          5
# Ticket         5
# Fare           5
# Cabin          5
# Embarked       5
# isChild        5
# dtype: int64

# %%
df_titanic[(df_titanic.SibSp == 3) & (df_titanic.Survived == 1)].count()
# Out:
# PassengerId    2
# Survived       2
# Pclass         2
# Name           2
# Sex            2
# Age            2
# SibSp          2
# Parch          2
# Ticket         2
# Fare           2
# Cabin          2
# Embarked       2
# isChild        2
# dtype: int64

# %%
df_titanic[(df_titanic.Pclass == 3) & (df_titanic.Survived == 0)].count()
# Out:
# PassengerId    10
# Survived       10
# Pclass         10
# Name           10
# Sex            10
# Age            10
# SibSp          10
# Parch          10
# Ticket         10
# Fare           10
# Cabin          10
# Embarked       10
# isChild        10
# dtype: int64

# %%
df_titanic[(df_titanic.isChild == 0) & (df_titanic.Survived == 1)].count()
# Out:
# PassengerId    124
# Survived       124
# Pclass         124
# Name           124
# Sex            124
# Age            124
# SibSp          124
# Parch          124
# Ticket         124
# Fare           124
# Cabin          124
# Embarked       124
# isChild        124
# dtype: int64
